# %% [markdown]
# Importamos las librerías:

# %%
#Importamos librerias

import camelot
import pandas as pd
import datetime
from funciones import tabla_a_datos, campos_calculados, separar_columna, juntar_columnas
import glob

# %% [markdown]
# Con *camelot* leemos el pdf que le digamos y extraemos las tablas en bruto:

# %%
## Datos a importar

file = 'NATACION_BENJAMIN_4_RESULTADOS_2122.pdf'
tablas = camelot.read_pdf(file, pages='all', flavor='stream', split_text='\n')
tablas.n
# Out:
# 14

# %% [markdown]
# Modificamos las tablas

# %%
t0=separar_columna(tablas[0].df[tablas[0].df[0]!=''][4:],1)
t1 = tablas[1].df[tablas[1].df[0]!=''][3:].drop(8,axis=1).T.reset_index(drop=True).T
t1 = separar_columna(separar_columna(t1,0).fillna(value=''),0,' ').fillna(value='')
t1 = juntar_columnas(juntar_columnas(t1,1,6),3,4)
t1[1]=t1[1].replace({'MENDEZSALVADOR, Carlos':'MENDEZ SALVADOR, Carlos',
                       'PETISMEROYO, Lucas':'PETISME ROYO, Lucas',
                     'RAMOS OLMOS,Diego':'RAMOS OLMOS, Diego',
                      'SANCHEZMERCADO, Adrian':'SANCHEZ MERCADO, Adrian',
                      'MOSTEOHIDALGO, Carlos':'MOSTEO HIDALGO, Carlos',
                      'BERDEJOLOBERA, Guillermo':'BERDEJO LOBERA, Guillermo',
                     'GREGORIO FERNANDEZ,Enrique':'GREGORIO FERNANDEZ, Enrique',
                      'JIMENEZLAFUENTE, Daniel':'JIMENEZ LAFUENTE, Daniel',
                     'SANCHEZSAEZ, Alejandro':'SANCHEZ SAEZ, Alejandro',
                     'SANZ BEJENARIU,Diego':'SANZ BEJENARIU, Diego',
                     'VICENTEBARRA,Guillen':'VICENTE BARRA, Guillen',
                     'RAZABALINGELMO, Angel':'RAZABAL INGELMO, Angel',
                     'NEVADOPEREZ, Lorien':'NEVADO PEREZ, Lorien'                  
                      })
t1[3]=t1[3].replace({'C.N.Helios':'C.N. Helios',
                       'P. SanAgustin':'P. San Agustin',
                      })

# t1b=pd.read_csv('tabla_perdida_20_02_22.csv',dtype=str, header=None).T.reset_index(drop=True).T
# t1b.to_dict()
dic ={0: {0: '21.', 1: '22.', 2: '23.', 3: '24.'},
 1: {0: 'SANTAMARIA FERRERUELA, Carlos',
  1: 'SANCHEZ DUARTE, Rodrigo',
  2: 'CUEZVA JORDAN, Hector',
  3: 'PEREZ DOMINCHE, Oriol'},
 2: {0: '10', 1: '10', 2: '10', 3: '10'},
 3: {0: 'P. San Agustin',
  1: 'Stadium Venecia',
  2: 'Stadium Venecia',
  3: 'C.N. Helios'},
 4: {0: '3:27.36', 1: '3:34.13', 2: '3:34.20', 3: '3:53.64'},
 5: {0: '110', 1: '99', 2: '99', 3: '76'}}
t1b=pd.DataFrame(dic)

t2=tablas[2].df[tablas[2].df[0]!=''][2:]
# separar_columna(t2,2).fillna(value='').loc[17]
t2.loc[17][1]='MARTINEZ MARQUES, Aimar Teresa'
t2.loc[17][2]='13'

# t2b=pd.read_csv('tabla_perdida2_20_02_22.csv',dtype=str, header=None).T.reset_index(drop=True).T
# t2b.to_dict()
dic={0: {0: '10.',
  1: '11.',
  2: '12.',
  3: '13.',
  4: '14.',
  5: '15.',
  6: '16.',
  7: '17.'},
 1: {0: 'GIMENO GOMEZ, Yaretzi Izel',
  1: 'REMACHA ROYO, Itziar',
  2: 'RODRIGO MONFORTE, Lucia',
  3: 'SALUEÑA LUCHA, Vera',
  4: 'BORREGUERO PEDREIRA, Leire',
  5: 'GALAY TORRIJO, Celia',
  6: 'MARIN PELEGRIN, Sara',
  7: 'MARIN PELEGRIN, Julia'},
 2: {0: '13', 1: '13', 2: '13', 3: '13', 4: '13', 5: '13', 6: '13', 7: '13'},
 3: {0: 'P. San Agustin',
  1: 'E.M. El Olivar',
  2: 'E.M. El Olivar',
  3: 'C.N. Helios',
  4: 'E.M. El Olivar',
  5: 'Stadium Venecia',
  6: 'H2ogo C.N.',
  7: 'H2ogo C.N.'},
 4: {0: '1:49.62',
  1: '1:53.45',
  2: '1:54.02',
  3: '1:57.72',
  4: '2:01.32',
  5: '2:03.50',
  6: '2:09.69',
  7: '2:09.74'},
 5: {0: '96', 1: '86', 2: '85', 3: '77', 4: '71', 5: '67', 6: '58', 7: '58'}}

t2b=pd.DataFrame(dic)

t2c=tablas[3].df[tablas[3].df[0]!=''][2:-2].drop(2,axis=1).T.reset_index(drop=True).T

t3=tablas[4].df[tablas[4].df[0]!=''][3:].drop(8,axis=1).T.reset_index(drop=True).T
t3 = separar_columna(separar_columna(t3,0).fillna(value=''),0,' ').fillna(value='')
t3 = juntar_columnas(juntar_columnas(t3,1,5),3,4)
t3[1]=t3[1].replace({'CASTILLOPRADO, Neus':'CASTILLO PRADO, Neus',
                       'LAMBANGAVE, Ines':'LAMBAN GAVE, Ines',
                     'SIMON HEREDIA,Ariadna':'SIMON HEREDIA, Ariadna',
                      'RAZABALINGELMO, Naiara':'RAZABAL INGELMO, Naiara',
                      'GIMENOMONREAL, Manuela':'GIMENO MONREAL, Manuela',
                      'PERALESCASAS, Laura':'PERALES CASAS, Laura',
                     'BARRACHINA ARTAZCOZ,Nahia':'BARRACHINA ARTAZCOZ, Nahia',
                      'ALONSOMORA,Naiara':'ALONSO MORA, Naiara',
                     'RAZABALINGELMO, Anahi':'RAZABAL INGELMO, Anahi',
                     'ORTEGAFRAGOSO, Emma':'ORTEGA FRAGOSO, Emma',
                     'RASAL ALVAREZ,Maria':'RASAL ALVAREZ, Maria',
                     'CEBRIANPUEYO, Carolina':'CEBRIAN PUEYO, Carolina',
                     'ROMEROLORENTE, Paula':'ROMERO LORENTE, Paula'                  
                      })
t3[3]=t3[3].replace({'C.N.Helios':'C.N. Helios',
                       'P. SanAgustin':'P. San Agustin',
                      })
t3b=tablas[5].df[tablas[5].df[0]!=''][3:].drop(8,axis=1).T.reset_index(drop=True).T
t3b = separar_columna(separar_columna(t3b,0).fillna(value=''),0,' ').fillna(value='')
t3b = juntar_columnas(juntar_columnas(t3b,1,6),3,4)
t3b[1]=t3b[1].replace({'CASTILLOPRADO, Neus':'CASTILLO PRADO, Neus',
                       'LAMBANGAVE, Ines':'LAMBAN GAVE, Ines',
                     'SIMON HEREDIA,Ariadna':'SIMON HEREDIA, Ariadna',
                      'RAZABALINGELMO, Naiara':'RAZABAL INGELMO, Naiara',
                      'GIMENOMONREAL, Manuela':'GIMENO MONREAL, Manuela',
                      'PERALESCASAS, Laura':'PERALES CASAS, Laura',
                     'BARRACHINA ARTAZCOZ,Nahia':'BARRACHINA ARTAZCOZ, Nahia',
                      'ALONSOMORA,Naiara':'ALONSO MORA, Naiara',
                     'RAZABALINGELMO, Anahi':'RAZABAL INGELMO, Anahi',
                     'ORTEGAFRAGOSO, Emma':'ORTEGA FRAGOSO, Emma',
                     'RASAL ALVAREZ,Maria':'RASAL ALVAREZ, Maria',
                     'CEBRIANPUEYO, Carolina':'CEBRIAN PUEYO, Carolina',
                     'ROMEROLORENTE, Paula':'ROMERO LORENTE, Paula'                  
                      })
t3b[3]=t3b[3].replace({'C.N.Helios':'C.N. Helios',
                       'P. SanAgustin':'P. San Agustin',
                      })

t4=separar_columna(tablas[6].df[tablas[6].df[0]!=''][2:],1)
t4.loc[19][1]='MODREGO MARQUETA, Alejandro'
t4.loc[19][2]='11'

# t4b=pd.read_csv('tabla_perdida3_20_02_22.csv',dtype=str, header=None).T.reset_index(drop=True).T
# t4b.to_dict()
dic={0: {0: '10.', 1: '11.'},
 1: {0: 'LOPEZ VELEZ, Marcos', 1: 'BEAMONTE MARTIN, Diego'},
 2: {0: '11', 1: '11'},
 3: {0: 'E.M. El Olivar', 1: 'P. San Agustin'},
 4: {0: '1:48.31', 1: '1:52.44'},
 5: {0: '133', 1: '119'}}
t4b=pd.DataFrame(dic)


t4c=tablas[7].df[tablas[7].df[0]!=''][2:-4]
t4c=separar_columna(t4c,1)

# %%
# Liga Benjamin

competicion = 'Benjamín, jornada 4'
lugar = 'E.M. El Olivar'
fecha = datetime.datetime(2022,2,20)


lista_df=[
tabla_a_datos(t0, fila_datos = 0, fecha=fecha, prueba='100m Libre', m_f='M', tipo=1, competicion=competicion, lugar= lugar),
tabla_a_datos(t1, fila_datos = 0, fecha=fecha, prueba='200m Libre', m_f='M', tipo=1, competicion=competicion, lugar= lugar),
tabla_a_datos(t1b, fila_datos = 0, fecha=fecha, prueba='200m Libre', m_f='M', tipo=1, competicion=competicion, lugar= lugar),
tabla_a_datos(t2, fila_datos = 0, fecha=fecha, prueba='100m Libre', m_f='F', tipo=1, competicion=competicion, lugar= lugar),
tabla_a_datos(t2b, fila_datos = 0, fecha=fecha, prueba='100m Libre', m_f='F', tipo=1, competicion=competicion, lugar= lugar),
tabla_a_datos(t2c, fila_datos = 0, fecha=fecha, prueba='100m Libre', m_f='F', tipo=1, competicion=competicion, lugar= lugar),
tabla_a_datos(t3, fila_datos = 0, fecha=fecha, prueba='200m Libre', m_f='F', tipo=1, competicion=competicion, lugar= lugar),
tabla_a_datos(t3b, fila_datos = 0, fecha=fecha, prueba='200m Libre', m_f='F', tipo=1, competicion=competicion, lugar= lugar),
tabla_a_datos(t4, fila_datos = 0, fecha=fecha, prueba='100m Libre', m_f='M', tipo=1, competicion=competicion, lugar= lugar),
tabla_a_datos(t4b, fila_datos = 0, fecha=fecha, prueba='100m Libre', m_f='M', tipo=1, competicion=competicion, lugar= lugar),
tabla_a_datos(t4c, fila_datos = 0, fecha=fecha, prueba='100m Libre', m_f='M', tipo=1, competicion=competicion, lugar= lugar),

    # tabla_a_datos(tablas[2].df.iloc[2:18].reset_index()[[0,1,2,3,5,6]].T.reset_index().T, fila_datos = 1, fecha=fecha, prueba='200m Estilos', m_f='M', tipo=3, competicion=competicion, lugar= lugar),
# tabla_a_datos(tabla_perdida, fila_datos = 0, fecha=fecha, prueba='100m Estilos', m_f='F', tipo=1, competicion=competicion, lugar= lugar),
# tabla_a_datos(tablas[5].df.drop(4, axis=1).iloc[4:], fila_datos = 1, fecha=fecha, prueba='200m Estilos', m_f='F', tipo=3, competicion=competicion, lugar= lugar),
# tabla_a_datos(tablas[6].df, fila_datos = 1, fecha=fecha, prueba='50m Mariposa', m_f='M', tipo=1, competicion=competicion, lugar= lugar),
# tabla_a_datos(tabla_perdida2, fila_datos = 0, fecha=fecha, prueba='50m Mariposa', m_f='M', tipo=1, competicion=competicion, lugar= lugar),
# tabla_a_datos(tablas[7].df, fila_datos = 1, fecha=fecha, prueba='50m Mariposa', m_f='M', tipo=1, competicion=competicion, lugar= lugar),
# tabla_a_datos(tablas[8].df, fila_datos = 1, fecha=fecha, prueba='50m Mariposa', m_f='F', tipo=1, competicion=competicion, lugar= lugar),
# tabla_a_datos(tablas[9].df.iloc[0:4], fila_datos = 0, fecha=fecha, prueba='50m Mariposa', m_f='F', tipo=1, competicion=competicion, lugar= lugar),
# tabla_a_datos(tabla_perdida3, fila_datos = 0, fecha=fecha, prueba='50m Mariposa', m_f='F', tipo=1, competicion=competicion, lugar= lugar),
# tabla_a_datos(tablas[10].df, fila_datos = 1, fecha=fecha, prueba='50m Mariposa', m_f='F', tipo=1, competicion=competicion, lugar= lugar),
]

for d in lista_df :
    display(d)
    
    
campos_calculados(pd.concat(lista_df)).to_csv('competicion_'+competicion+'.csv', index=False)
# Out:
#    Puesto                         Nombre Anyo_nac                Club  \
# 0      1.               MARCO LOPEZ, Leo       11         C.N. Helios
# 1      2.     RODRIGUEZ ARTIEDA, Marcelo       11         C.N. Helios
# 2      3.    MODREGO MARQUETA, Alejandro       11     Stadium Venecia
# 3      4.          CAVERO GARCIA, Daniel       11  Stadium Casablanca
# 4      5.            LOPEZ VELEZ, Marcos       11      E.M. El Olivar
# 5      6.          SERRABLO HUESO, Diego       11     Stadium Venecia
# 6      7.        BESCOS RODRIGUEZ, Jesus       11      E.M. El Olivar
# 7      8.          TATARU, Adrian Stefan       11      E.M. El Olivar
# 8      9.        MARTINEZ ANTUNEZ, Roman       11     Stadium Venecia
# 9     10.     ANTONENKO ANTONENKO, Yehor       11          H2ogo C.N.
# 10    11.          BELTRAN VIEJO, Arturo       11      E.M. El Olivar
# 11    12.          ANGUAS FELIZ, Aquiles       11      E.M. El Olivar
# 12    13.           FANDOS MARCO, Carlos       11      E.M. El Olivar
# 13    14.            SANCHO GRAUS, Bruno       11      E.M. El Olivar
# 14    15.         BEAMONTE MARTIN, Diego       11      P. San Agustin
# 15    16.          ROMERO SANTOS, Kilian       11         C.N. Helios
# 16    17.       ALCALDE MARTINEZ, Martin       11         C.N. Helios
# 17    18.      NAVARRO PARDOS, Francisco       11          H2ogo C.N.
# 18    19.            PELEGRIN RUIZ, Raul       11         C.N. Helios
# 19    20.  GARCIA DE LA SERNA, Alejandro       11         C.N. Helios
# 20    21.     BARCELONA PERALES, Beltran       11      E.M. El Olivar
# 21    22.            JIMENEZ VICO, Pedro       11         C.N. Helios
# 22    23.     QUINTANILLA CARBAJO, Amaro       11          H2ogo C.N.
#
#      Tiempo  Pts      Fecha      Prueba Piscina M_F          Competicion  \
# 0   1:14.26  221 2022-02-20  100m Libre     25m   M  Benjamín, jornada 4
# 1   1:18.56  187 2022-02-20  100m Libre     25m   M  Benjamín, jornada 4
# 2   1:18.68  186 2022-02-20  100m Libre     25m   M  Benjamín, jornada 4
# 3   1:19.50  180 2022-02-20  100m Libre     25m   M  Benjamín, jornada 4
# 4   1:20.72  172 2022-02-20  100m Libre     25m   M  Benjamín, jornada 4
# 5   1:21.62  166 2022-02-20  100m Libre     25m   M  Benjamín, jornada 4
# 6   1:22.10  164 2022-02-20  100m Libre     25m   M  Benjamín, jornada 4
# 7   1:23.95  153 2022-02-20  100m Libre     25m   M  Benjamín, jornada 4
# 8   1:25.41  145 2022-02-20  100m Libre     25m   M  Benjamín, jornada 4
# 9   1:25.42  145 2022-02-20  100m Libre     25m   M  Benjamín, jornada 4
# 10  1:26.42  140 2022-02-20  100m Libre     25m   M  Benjamín, jornada 4
# 11  1:27.50  135 2022-02-20  100m Libre     25m   M  Benjamín, jornada 4
# 12  1:28.38  131 2022-02-20  100m Libre     25m   M  Benjamín, jornada 4
# 13  1:28.48  131 2022-02-20  100m Libre     25m   M  Benjamín, jornada 4
# 14  1:31.83  117 2022-02-20  100m Libre     25m   M  Benjamín, jornada 4
# 15  1:33.69  110 2022-02-20  100m Libre     25m   M  Benjamín, jornada 4
# 16  1:36.13  102 2022-02-20  100m Libre     25m   M  Benjamín, jornada 4
# 17  1:37.09   99 2022-02-20  100m Libre     25m   M  Benjamín, jornada 4
# 18  1:38.69   94 2022-02-20  100m Libre     25m   M  Benjamín, jornada 4
# 19  1:43.72   81 2022-02-20  100m Libre     25m   M  Benjamín, jornada 4
# 20  1:47.42   73 2022-02-20  100m Libre     25m   M  Benjamín, jornada 4
# 21  1:56.60   57 2022-02-20  100m Libre     25m   M  Benjamín, jornada 4
# 22  2:05.83   45 2022-02-20  100m Libre     25m   M  Benjamín, jornada 4
#
#              Lugar
# 0   E.M. El Olivar
# 1   E.M. El Olivar
# 2   E.M. El Olivar
# 3   E.M. El Olivar
# 4   E.M. El Olivar
# 5   E.M. El Olivar
# 6   E.M. El Olivar
# 7   E.M. El Olivar
# 8   E.M. El Olivar
# 9   E.M. El Olivar
# 10  E.M. El Olivar
# 11  E.M. El Olivar
# 12  E.M. El Olivar
# 13  E.M. El Olivar
# 14  E.M. El Olivar
# 15  E.M. El Olivar
# 16  E.M. El Olivar
# 17  E.M. El Olivar
# 18  E.M. El Olivar
# 19  E.M. El Olivar
# 20  E.M. El Olivar
# 21  E.M. El Olivar
# 22  E.M. El Olivar
#    Puesto                           Nombre Anyo_nac                Club  \
# 0      1.          MENDEZ SALVADOR, Carlos       10         C.N. Teruel
# 1      2.            MARTIN FERNANDEZ, Leo       10      E.M. El Olivar
# 2      3.              PETISME ROYO, Lucas       10      E.M. El Olivar
# 3      4.               RAMOS OLMOS, Diego       10      P. San Agustin
# 4      5.          BARRIENDOS ZAMORA, Saul       10         C.N. Helios
# 5      6.          SANCHEZ MERCADO, Adrian       10  Stadium Casablanca
# 6      7.           MOSTEO HIDALGO, Carlos       10      E.M. El Olivar
# 7      8.               RAMOS OLMOS,Marcos       10      P. San Agustin
# 8      9.             ESTAUN LOPEZ, Marcos       10         C.N. Helios
# 9     10.        BERDEJO LOBERA, Guillermo       10      E.M. El Olivar
# 10    11.      GREGORIO FERNANDEZ, Enrique       10      P. San Agustin
# 11    12.         JIMENEZ LAFUENTE, Daniel       10         C.N. Helios
# 12    13.  RUBIO RAKITIN, Larion Francisco       10         C.N. Helios
# 13    14.          SANCHEZ SAEZ, Alejandro       10      P. San Agustin
# 14    15.            SANZ BEJENARIU, Diego       10      C.N. Iz Cuarte
# 15    16.           VICENTE BARRA, Guillen       10          H2ogo C.N.
# 16    17.           RAZABAL INGELMO, Angel       10      E.M. El Olivar
# 17    18.               AGON LOPEZ, Javier       10  Stadium Casablanca
# 18    19.             NEVADO PEREZ, Lorien       10         C.N. Helios
# 19    20.              TELLO GRACIA, Aaron       10         C.N. Helios
#
#      Tiempo  Pts      Fecha      Prueba Piscina M_F          Competicion  \
# 0   2:39.66  241 2022-02-20  200m Libre     25m   M  Benjamín, jornada 4
# 1   2:41.56  232 2022-02-20  200m Libre     25m   M  Benjamín, jornada 4
# 2   2:43.39  224 2022-02-20  200m Libre     25m   M  Benjamín, jornada 4
# 3   2:49.32  202 2022-02-20  200m Libre     25m   M  Benjamín, jornada 4
# 4   2:50.36  198 2022-02-20  200m Libre     25m   M  Benjamín, jornada 4
# 5   2:52.39  191 2022-02-20  200m Libre     25m   M  Benjamín, jornada 4
# 6   2:59.26  170 2022-02-20  200m Libre     25m   M  Benjamín, jornada 4
# 7   2:59.54  169 2022-02-20  200m Libre     25m   M  Benjamín, jornada 4
# 8   3:00.69  166 2022-02-20  200m Libre     25m   M  Benjamín, jornada 4
# 9   3:01.15  165 2022-02-20  200m Libre     25m   M  Benjamín, jornada 4
# 10  3:01.70  163 2022-02-20  200m Libre     25m   M  Benjamín, jornada 4
# 11  3:02.32  161 2022-02-20  200m Libre     25m   M  Benjamín, jornada 4
# 12  3:04.64  155 2022-02-20  200m Libre     25m   M  Benjamín, jornada 4
# 13  3:07.97  147 2022-02-20  200m Libre     25m   M  Benjamín, jornada 4
# 14  3:11.38  139 2022-02-20  200m Libre     25m   M  Benjamín, jornada 4
# 15  3:13.44  135 2022-02-20  200m Libre     25m   M  Benjamín, jornada 4
# 16  3:13.84  134 2022-02-20  200m Libre     25m   M  Benjamín, jornada 4
# 17  3:15.25  131 2022-02-20  200m Libre     25m   M  Benjamín, jornada 4
# 18  3:21.09  120 2022-02-20  200m Libre     25m   M  Benjamín, jornada 4
# 19  3:24.97  113 2022-02-20  200m Libre     25m   M  Benjamín, jornada 4
#
#              Lugar
# 0   E.M. El Olivar
# 1   E.M. El Olivar
# 2   E.M. El Olivar
# 3   E.M. El Olivar
# 4   E.M. El Olivar
# 5   E.M. El Olivar
# 6   E.M. El Olivar
# 7   E.M. El Olivar
# 8   E.M. El Olivar
# 9   E.M. El Olivar
# 10  E.M. El Olivar
# 11  E.M. El Olivar
# 12  E.M. El Olivar
# 13  E.M. El Olivar
# 14  E.M. El Olivar
# 15  E.M. El Olivar
# 16  E.M. El Olivar
# 17  E.M. El Olivar
# 18  E.M. El Olivar
# 19  E.M. El Olivar
#   Puesto                         Nombre Anyo_nac             Club   Tiempo  \
# 0    21.  SANTAMARIA FERRERUELA, Carlos       10   P. San Agustin  3:27.36
# 1    22.        SANCHEZ DUARTE, Rodrigo       10  Stadium Venecia  3:34.13
# 2    23.          CUEZVA JORDAN, Hector       10  Stadium Venecia  3:34.20
# 3    24.          PEREZ DOMINCHE, Oriol       10      C.N. Helios  3:53.64
#
#    Pts      Fecha      Prueba Piscina M_F          Competicion           Lugar
# 0  110 2022-02-20  200m Libre     25m   M  Benjamín, jornada 4  E.M. El Olivar
# 1   99 2022-02-20  200m Libre     25m   M  Benjamín, jornada 4  E.M. El Olivar
# 2   99 2022-02-20  200m Libre     25m   M  Benjamín, jornada 4  E.M. El Olivar
# 3   76 2022-02-20  200m Libre     25m   M  Benjamín, jornada 4  E.M. El Olivar
#   Puesto                          Nombre Anyo_nac             Club   Tiempo  \
# 0     1.             MALON CANTIN, Sofia       13      C.N. Helios  1:31.40
# 1     2.         RODRIGUEZ SOLANAS, Ines       13   E.M. El Olivar  1:31.41
# 2     3.   GAINSINSKY CASTILLO, Michelle       13      C.N. Helios  1:38.57
# 3     4.        RODRIGO LORENTE, Claudia       13  Stadium Venecia  1:40.56
# 4     5.           MARTIN SORIA, Claudia       13  Stadium Venecia  1:40.91
# 5     6.             MALO SANCHEZ, Paula       13      C.N. Helios  1:43.50
# 6     7.      ESCORIHUELA AZNAR, Claudia       13   E.M. El Olivar  1:45.39
# 7     8.  MARTINEZ MARQUES, Aimar Teresa       13  Stadium Venecia  1:48.23
# 8     9.          LEAL PELEGRIN, Julieta       13   E.M. El Olivar  1:48.82
#
#    Pts      Fecha      Prueba Piscina M_F          Competicion           Lugar
# 0  166 2022-02-20  100m Libre     25m   F  Benjamín, jornada 4  E.M. El Olivar
# 1  166 2022-02-20  100m Libre     25m   F  Benjamín, jornada 4  E.M. El Olivar
# 2  132 2022-02-20  100m Libre     25m   F  Benjamín, jornada 4  E.M. El Olivar
# 3  124 2022-02-20  100m Libre     25m   F  Benjamín, jornada 4  E.M. El Olivar
# 4  123 2022-02-20  100m Libre     25m   F  Benjamín, jornada 4  E.M. El Olivar
# 5  114 2022-02-20  100m Libre     25m   F  Benjamín, jornada 4  E.M. El Olivar
# 6  108 2022-02-20  100m Libre     25m   F  Benjamín, jornada 4  E.M. El Olivar
# 7  100 2022-02-20  100m Libre     25m   F  Benjamín, jornada 4  E.M. El Olivar
# 8   98 2022-02-20  100m Libre     25m   F  Benjamín, jornada 4  E.M. El Olivar
#   Puesto                      Nombre Anyo_nac             Club   Tiempo Pts  \
# 0    10.  GIMENO GOMEZ, Yaretzi Izel       13   P. San Agustin  1:49.62  96
# 1    11.        REMACHA ROYO, Itziar       13   E.M. El Olivar  1:53.45  86
# 2    12.     RODRIGO MONFORTE, Lucia       13   E.M. El Olivar  1:54.02  85
# 3    13.         SALUEÑA LUCHA, Vera       13      C.N. Helios  1:57.72  77
# 4    14.  BORREGUERO PEDREIRA, Leire       13   E.M. El Olivar  2:01.32  71
# 5    15.        GALAY TORRIJO, Celia       13  Stadium Venecia  2:03.50  67
# 6    16.        MARIN PELEGRIN, Sara       13       H2ogo C.N.  2:09.69  58
# 7    17.       MARIN PELEGRIN, Julia       13       H2ogo C.N.  2:09.74  58
#
#        Fecha      Prueba Piscina M_F          Competicion           Lugar
# 0 2022-02-20  100m Libre     25m   F  Benjamín, jornada 4  E.M. El Olivar
# 1 2022-02-20  100m Libre     25m   F  Benjamín, jornada 4  E.M. El Olivar
# 2 2022-02-20  100m Libre     25m   F  Benjamín, jornada 4  E.M. El Olivar
# 3 2022-02-20  100m Libre     25m   F  Benjamín, jornada 4  E.M. El Olivar
# 4 2022-02-20  100m Libre     25m   F  Benjamín, jornada 4  E.M. El Olivar
# 5 2022-02-20  100m Libre     25m   F  Benjamín, jornada 4  E.M. El Olivar
# 6 2022-02-20  100m Libre     25m   F  Benjamín, jornada 4  E.M. El Olivar
# 7 2022-02-20  100m Libre     25m   F  Benjamín, jornada 4  E.M. El Olivar
#   Puesto                   Nombre Anyo_nac             Club   Tiempo Pts  \
# 0    18.   GARCIA RODRIGUEZ, Aroa       13      C.N. Helios  2:13.15  53
# 1    19.     GARCIA ZABAL, Carmen       13   P. San Agustin  2:21.81  44
# 2    20.  IZQUIERDO GRACIA, Maria       13  Stadium Venecia  2:34.51  34
# 3    21.     MATA AGUELA, Candela       13   E.M. El Olivar  3:04.75  20
#
#        Fecha      Prueba Piscina M_F          Competicion           Lugar
# 0 2022-02-20  100m Libre     25m   F  Benjamín, jornada 4  E.M. El Olivar
# 1 2022-02-20  100m Libre     25m   F  Benjamín, jornada 4  E.M. El Olivar
# 2 2022-02-20  100m Libre     25m   F  Benjamín, jornada 4  E.M. El Olivar
# 3 2022-02-20  100m Libre     25m   F  Benjamín, jornada 4  E.M. El Olivar
#    Puesto                      Nombre Anyo_nac                Club   Tiempo  \
# 0      1.        CASTILLO PRADO, Neus       12      E.M. El Olivar  3:02.34
# 1      2.           LAMBAN GAVE, Ines       12      P. San Agustin  3:03.86
# 2      3.                IOVU, Mireya       12      P. San Agustin  3:12.81
# 3      4.        BERGES ALAEZ, Africa       12      E.M. El Olivar  3:17.72
# 4      5.         GIL FUENTES, Izarbe       12     Stadium Venecia  3:17.95
# 5      6.      SIMON HEREDIA, Ariadna       12      E.M. El Olivar  3:23.89
# 6      7.       ALBAR LABRADOR, Pilar       12      E.M. El Olivar  3:23.94
# 7      8.     RAZABAL INGELMO, Naiara       12      E.M. El Olivar  3:27.53
# 8      9.     GIMENO MONREAL, Manuela       12      E.M. El Olivar  3:29.23
# 9     10.        PERALES CASAS, Laura       12      E.M. El Olivar  3:29.32
# 10    11.  BARRACHINA ARTAZCOZ, Nahia       12      E.M. El Olivar  3:29.67
# 11    12.         ALONSO MORA, Naiara       12     Stadium Venecia  3:33.67
# 12    13.      RAZABAL INGELMO, Anahi       12      E.M. El Olivar  3:35.42
# 13    14.  SAN MIGUEL PUYUELO, Angela       12  Stadium Casablanca  3:40.06
# 14    15.       BERGES ALAEZ, Daniela       12      E.M. El Olivar  3:44.60
# 15    16.        ORTEGA FRAGOSO, Emma       12     Stadium Venecia  3:47.80
#
#     Pts      Fecha      Prueba Piscina M_F          Competicion  \
# 0   222 2022-02-20  200m Libre     25m   F  Benjamín, jornada 4
# 1   216 2022-02-20  200m Libre     25m   F  Benjamín, jornada 4
# 2   187 2022-02-20  200m Libre     25m   F  Benjamín, jornada 4
# 3   174 2022-02-20  200m Libre     25m   F  Benjamín, jornada 4
# 4   173 2022-02-20  200m Libre     25m   F  Benjamín, jornada 4
# 5   158 2022-02-20  200m Libre     25m   F  Benjamín, jornada 4
# 6   158 2022-02-20  200m Libre     25m   F  Benjamín, jornada 4
# 7   150 2022-02-20  200m Libre     25m   F  Benjamín, jornada 4
# 8   147 2022-02-20  200m Libre     25m   F  Benjamín, jornada 4
# 9   146 2022-02-20  200m Libre     25m   F  Benjamín, jornada 4
# 10  146 2022-02-20  200m Libre     25m   F  Benjamín, jornada 4
# 11  138 2022-02-20  200m Libre     25m   F  Benjamín, jornada 4
# 12  134 2022-02-20  200m Libre     25m   F  Benjamín, jornada 4
# 13  126 2022-02-20  200m Libre     25m   F  Benjamín, jornada 4
# 14  118 2022-02-20  200m Libre     25m   F  Benjamín, jornada 4
# 15  113 2022-02-20  200m Libre     25m   F  Benjamín, jornada 4
#
#              Lugar
# 0   E.M. El Olivar
# 1   E.M. El Olivar
# 2   E.M. El Olivar
# 3   E.M. El Olivar
# 4   E.M. El Olivar
# 5   E.M. El Olivar
# 6   E.M. El Olivar
# 7   E.M. El Olivar
# 8   E.M. El Olivar
# 9   E.M. El Olivar
# 10  E.M. El Olivar
# 11  E.M. El Olivar
# 12  E.M. El Olivar
# 13  E.M. El Olivar
# 14  E.M. El Olivar
# 15  E.M. El Olivar
#   Puesto                        Nombre Anyo_nac                Club   Tiempo  \
# 0    18.      IRIMIA MICU, Paula Raisa       12      P. San Agustin  3:53.91
# 1    19.          RASAL ALVAREZ, Maria       12      P. San Agustin  3:54.99
# 2    20.  GALIPIENZO NAVARRO, Cristina       12     Stadium Venecia  3:55.64
# 3    21.      DEL REAL MUNIENTE, Elena       12      P. San Agustin  4:06.91
# 4    22.          SANCHEZ AGUADO, Enma       12  Stadium Casablanca  4:08.36
# 5    23.       CEBRIAN PUEYO, Carolina       12      P. San Agustin  4:09.23
# 6    24.     GALIPIENZO NAVARRO, Paula       12     Stadium Venecia  4:18.12
# 7    25.              PES URREA, Pilar       12      P. San Agustin  4:18.31
# 8    26.         ROMERO LORENTE, Paula       12      P. San Agustin  4:50.13
#
#    Pts      Fecha      Prueba Piscina M_F          Competicion           Lugar
# 0  105 2022-02-20  200m Libre     25m   F  Benjamín, jornada 4  E.M. El Olivar
# 1  103 2022-02-20  200m Libre     25m   F  Benjamín, jornada 4  E.M. El Olivar
# 2  102 2022-02-20  200m Libre     25m   F  Benjamín, jornada 4  E.M. El Olivar
# 3   89 2022-02-20  200m Libre     25m   F  Benjamín, jornada 4  E.M. El Olivar
# 4   87 2022-02-20  200m Libre     25m   F  Benjamín, jornada 4  E.M. El Olivar
# 5   86 2022-02-20  200m Libre     25m   F  Benjamín, jornada 4  E.M. El Olivar
# 6   78 2022-02-20  200m Libre     25m   F  Benjamín, jornada 4  E.M. El Olivar
# 7   78 2022-02-20  200m Libre     25m   F  Benjamín, jornada 4  E.M. El Olivar
# 8   55 2022-02-20  200m Libre     25m   F  Benjamín, jornada 4  E.M. El Olivar

# %% [markdown]
# Hacemos un resumen de los datos contando el número de nadadores por club:

# %%
# Resumen de datos

df=pd.read_csv('competicion_'+competicion+'.csv')

#df.pivot_table(df, values = 'Nombre',index='M_F', columns=['Club','Anyo_nac'], aggfunc=lambda x: len(x.unique()))
df.pivot_table(values = 'Nombre', columns='M_F', index=['Club','Anyo_nac'], aggfunc=lambda x: len(x.unique())).unstack().fillna(0).astype(int)
# Out:
# M_F                 M
# Anyo_nac           10 11
# Club
# C.N. Helios         6  7
# C.N. Iz Cuarte      1  0
# C.N. Teruel         1  0
# E.M. El Olivar      5  8
# H2ogo C.N.          1  3
# P. San Agustin      4  1
# Stadium Casablanca  2  1
# Stadium Venecia     0  3

# %% [markdown]
# Por último, añadimos todas las competiciones al archivo *base_datos.csv*:

# %%
# Actualizamos la base de datos

import glob

# Buscamos todos los ficheros csv correspondientes a competiciones los concatenamos y los grabamos en base de datos

lista_competiciones = glob.glob('competicion*.csv')
# lista_competiciones.reverse()
lista_competiciones.sort()
df=pd.concat([pd.read_csv(comp) for comp in lista_competiciones])
# df.sort_values(by='Fecha').to_csv('base_datos.csv', index=False)
df.to_csv('base_datos.csv', index=False)

# lista_competiciones.reverse()
lista_competiciones
# Out:
# ['competicion_Benjamín, jornada 1.csv',
#  'competicion_Benjamín, jornada 2.csv',
#  'competicion_Benjamín, jornada 3.csv',
#  'competicion_Benjamín, jornada 4.csv']
